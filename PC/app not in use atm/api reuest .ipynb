# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = 'http://www.patentsview.org/api/locations/query?q={"assignee_first_name":["cardozo","lewis","duperval"]}&f=["assignee_lastknown_city","assignee_lastknown_state","assignee_lastknown_country"]'

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# {'locations': [{'assignees': [{'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '19226'}, {'assignee_lastknown_city': 'Sejong-si', 'assignee_lastknown_state': None, 'assignee_lastknown_country': 'KR', 'assignee_key_id': '157365'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '122485'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '74790'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '309615'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '72736'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '353959'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '473368'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '120244'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '51365'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '67135'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '459216'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '439205'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '148496'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '19996'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '55534'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '352138'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '448164'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '473362'}, {'assignee_lastknown_city': 'Blossom Valley', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '419041'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '237790'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '77084'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '403880'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '62760'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '311577'}, {'assignee_lastknown_city': 'San Diego', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '347890'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '27732'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country': 'US', 'assignee_key_id': '359058'}, {'assignee_lastknown_city': 'Santee', 'assignee_lastknown_state': 'CA', 'assignee_lastknown_country':  ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 6,
#     "locations": [
#         {
#             "assignees": [
#                 {
#                     "assignee_key_id": "19226",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "157365",
#                     "assignee_lastknown_city": "Sejong-si",
#                     "assignee_lastknown_country": "KR",
#                     "assignee_lastknown_state": null
#                 },
#                 {
#                     "assignee_key_id": "122485",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "74790",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "309615",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "72736",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "353959",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "473368",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "120244",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "51365",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "67135",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "459216",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "439205",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "148496",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "19996",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "55534",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "352138",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "448164",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "473362",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "419041",
#                     "assignee_lastknown_city": "Blossom Valley",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "237790",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "77084",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "403880",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "62760",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "311577",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "347890",
#                     "assignee_lastknown_city": "San Diego",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "27732",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "359058",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "467632",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "374327",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "242378",
#                     "assignee_lastknown_city": "El Cajon",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "338427",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "29841",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "394633",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "289263",
#                     "assignee_lastknown_city": "Santa Clara",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "193600",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "54803",
#                     "assignee_lastknown_city": "Santa Fe Springs",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "85655",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "232765",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "287426",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "410919",
#                     "assignee_lastknown_city": "Lakeside",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "243239",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "282033",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "479993",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "187375",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "94430",
#                     "assignee_lastknown_city": "San Diego",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "66612",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "142250",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "20207",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "317959",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "468397",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "241747",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "53283",
#                     "assignee_lastknown_city": "San Diego",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "280761",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "458519",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "478645",
#                     "assignee_lastknown_city": "Santee",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 }
#             ]
#         },
#         {
#             "assignees": [
#                 {
#                     "assignee_key_id": "433500",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "160124",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "318307",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "448877",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "457014",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "53839",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "177469",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "442266",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "166944",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "290340",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "407064",
#                     "assignee_lastknown_city": "Portland",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "OR"
#                 },
#                 {
#                     "assignee_key_id": "316681",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "333094",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "27613",
#                     "assignee_lastknown_city": "Lexington",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "MA"
#                 },
#                 {
#                     "assignee_key_id": "476085",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "180167",
#                     "assignee_lastknown_city": "Longmont",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CO"
#                 },
#                 {
#                     "assignee_key_id": "47994",
#                     "assignee_lastknown_city": "Stamford",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CT"
#                 },
#                 {
#                     "assignee_key_id": "222750",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "112760",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "463874",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "446765",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "52530",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "461363",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "458923",
#                     "assignee_lastknown_city": "Katonah",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 }
#             ]
#         },
#         {
#             "assignees": [
#                 {
#                     "assignee_key_id": "327197",
#                     "assignee_lastknown_city": "Buffalo",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "334089",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "176075",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "56719",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "169823",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "283951",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "264117",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "190860",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "38997",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "424259",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "270948",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "311377",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "362660",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "19691",
#                     "assignee_lastknown_city": "Niskayuna",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "99808",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "52439",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "431350",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "384550",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "421365",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "269497",
#                     "assignee_lastknown_city": "Rochester",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NH"
#                 },
#                 {
#                     "assignee_key_id": "407954",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "133241",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "443938",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "454642",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "457198",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "231082",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "249198",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "284059",
#                     "assignee_lastknown_city": "Amherst",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "73220",
#                     "assignee_lastknown_city": "Binghamton",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "468498",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "211146",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "306754",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "435868",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "117178",
#                     "assignee_lastknown_city": "Menands",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "114230",
#                     "assignee_lastknown_city": "Buffalo",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "302366",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "20916",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "236616",
#                     "assignee_lastknown_city": "East Greenbush",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "133309",
#                     "assignee_lastknown_city": "Boston",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "MA"
#                 },
#                 {
#                     "assignee_key_id": "13112",
#                     "assignee_lastknown_city": "La Jolla",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "CA"
#                 },
#                 {
#                     "assignee_key_id": "243564",
#                     "assignee_lastknown_city": "Alamogordo",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NM"
#                 },
#                 {
#                     "assignee_key_id": "36430",
#                     "assignee_lastknown_city": "Calgary",
#                     "assignee_lastknown_country": "CA",
#                     "assignee_lastknown_state": null
#                 },
#                 {
#                     "assignee_key_id": "403201",
#                     "assignee_lastknown_city": null,
#                     "assignee_lastknown_country": null,
#                     "assignee_lastknown_state": null
#                 },
#                 {
#                     "assignee_key_id": "301165",
#                     "assignee_lastknown_city": "Schenectady",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "320192",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "417122",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "109467",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "469596",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "30955",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "78181",
#                     "assignee_lastknown_city": "Schenectady",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "452283",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "392459",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "61345",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "13366",
#                     "assignee_lastknown_city": "Stony Brook",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "53222",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "328221",
#                     "assignee_lastknown_city": "Amherst",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "263952",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "385325",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "176409",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "294925",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "267489",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "180411",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "412457",
#                     "assignee_lastknown_city": "Amherst",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "210660",
#                     "assignee_lastknown_city": "East Greenbush",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "25251",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "364238",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "429111",
#                     "assignee_lastknown_city": "Westborough",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "MA"
#                 },
#                 {
#                     "assignee_key_id": "210679",
#                     "assignee_lastknown_city": "New York",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "100817",
#                     "assignee_lastknown_city": "Troy",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "355596",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "105443",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "139505",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "411639",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "303590",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "172388",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "149561",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "346042",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "136687",
#                     "assignee_lastknown_city": "Rexford",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "208828",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "225318",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "373034",
#                     "assignee_lastknown_city": "Rensselaer",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "397616",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "31101",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "12852",
#                     "assignee_lastknown_city": "Watervliet",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "348673",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "55553",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "182917",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "390952",
#                     "assignee_lastknown_city": "New Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "IN"
#                 },
#                 {
#                     "assignee_key_id": "161411",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "147705",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "366940",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "320686",
#                     "assignee_lastknown_city": "St. Louis",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "MO"
#                 },
#                 {
#                     "assignee_key_id": "20513",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "387358",
#                     "assignee_lastknown_city": "Troy",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "422422",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "75492",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "476966",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "48147",
#                     "assignee_lastknown_city": "Waterford",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "263514",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "208637",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "86099",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "308852",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "30032",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "92204",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "283421",
#                     "assignee_lastknown_city": "Menands",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "49380",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "375257",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "298179",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "49063",
#                     "assignee_lastknown_city": "Albany",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "391604",
# ...
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "159588",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "168804",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "86910",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "231315",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "306107",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "317009",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "28550",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "120228",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "251423",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "84338",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "412133",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "344642",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "71025",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "18494",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "203578",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "393788",
#                     "assignee_lastknown_city": "Palm Bay",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "FL"
#                 },
#                 {
#                     "assignee_key_id": "166796",
#                     "assignee_lastknown_city": "Ft. Payne",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "AL"
#                 },
#                 {
#                     "assignee_key_id": "376137",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "440867",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "113333",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "285554",
#                     "assignee_lastknown_city": "Edgerton",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "116029",
#                     "assignee_lastknown_city": "Potomac",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "MD"
#                 },
#                 {
#                     "assignee_key_id": "209119",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "139160",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "411047",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "334046",
#                     "assignee_lastknown_city": "Chattanooga",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "TN"
#                 },
#                 {
#                     "assignee_key_id": "177682",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "211406",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "100190",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "416988",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "37961",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "321057",
#                     "assignee_lastknown_city": "Chattanooga",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "TN"
#                 },
#                 {
#                     "assignee_key_id": "303774",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "241486",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "267502",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "357898",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "229017",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "363215",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "8897",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "215691",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "428606",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "38296",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "109100",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "323921",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "414270",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "132574",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "357032",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "292752",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "357982",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "68870",
#                     "assignee_lastknown_city": "Bronxville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "NY"
#                 },
#                 {
#                     "assignee_key_id": "265993",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "465491",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "279581",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "305704",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "400331",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "480485",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "478131",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "157690",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "246382",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "281957",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "454922",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 },
#                 {
#                     "assignee_key_id": "429268",
#                     "assignee_lastknown_city": "Janesville",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "WI"
#                 }
#             ]
#         }
#     ],
#     "total_location_count": 6
# }
