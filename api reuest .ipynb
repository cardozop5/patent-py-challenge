# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url =a'http://www.patentsview.org/api/locations/query?q={"inventor_last_name":["cardozo","lewis","duperval"]}&f=["assignee_lastknown_longitude","assignee_lastknown_latitude","assignee_lastknown_country"]'

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
#print(requests.get(url).json())

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 25,
#     "locations": [
#         {
#             "assignees": [
#                 {
#                     "assignee_key_id": "326745",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_latitude": "32.9125",
#                     "assignee_lastknown_longitude": "-96.6386"
#                 },
#                 {
#                     "assignee_key_id": "9731",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_latitude": "32.9125",
#                     "assignee_lastknown_longitude": "-96.6386"
#                 },
#                 {
#                     "assignee_key_id": "329786",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_latitude": "32.9125",
#                     "assignee_lastknown_longitude": "-96.6386"
#                 },
#                 {
#                     "assignee_key_id": "77129",
# ...

# %%
response
# Out:
# {'locations': [{'assignees': [{'assignee_lastknown_longitude': '-96.6386',
#      'assignee_lastknown_latitude': '32.9125',
#      'assignee_lastknown_country': 'US',
#      'assignee_key_id': '326745'},
#     {'assignee_lastknown_longitude': '-96.6386',
#      'assignee_lastknown_latitude': '32.9125',
#      'assignee_lastknown_country': 'US',
#      'assignee_key_id': '9731'},
#     {'assignee_lastknown_longitude': '-96.6386',
#      'assignee_lastknown_latitude': '32.9125',
#      'assignee_lastknown_country': 'US',
#      'assignee_key_id': '329786'},
#     {'assignee_lastknown_longitude': '-96.6386',
#      'assignee_lastknown_latitude': '32.9125',
#      'assignee_lastknown_country': 'US',
#      'assignee_key_id': '77129'},
#     {'assignee_lastknown_longitude': '-96.6386',
#      'assignee_lastknown_latitude': '32.9125',
#      'assignee_lastknown_country': 'US',
#      'assignee_key_id': '16873'},
#     {'assignee_lastknown_longitude': '-96.6386',
# ...

# %%
import pandas as pd
import os

# %%
response.keys()
# Out:
# dict_keys(['locations', 'count', 'total_location_count'])

# %%
type(response['locations'])
# Out:
# list

# %%
df=pd.io.json.json_normalize(response['locations'])

# %%
df2=pd.DataFrame()

# %%
df1=pd.DataFrame(df['assignees'][0])
df3=df1.append(pd.DataFrame(df['assignees'][1]))
df3.shape
# Out:
# (166, 4)

# %%
df1=pd.DataFrame(df['assignees'][0])
for i in range(1,25):
    df1.append(pd.DataFrame(df['assignees'][i]))
df1
# Out:
#     assignee_key_id assignee_lastknown_country assignee_lastknown_latitude  \
# 0            326745                         US                     32.9125
# 1              9731                         US                     32.9125
# 2            329786                         US                     32.9125
# 3             77129                         US                     32.9125
# 4             16873                         US                     32.9125
# 5            243098                         US                     32.9125
# 6            127202                         US                     32.9125
# 7             99503                         US                     32.9125
# 8            182619                         US                     32.5006
# 9             96909                         US                     32.9125
# 10           239510                         US                     32.9125
# ...

# %%
df1.to_csv('./my.csv')

# %%
# !pip install folium

# %%
# !python3 -m pip install folium

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-179-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
a=[]
for i in range(0,25):
    a.append(len(df['assignees'][i]))

# %%
sum(a)
# Out:
# 1149

# %%
a
# Out:
# [147,
#  19,
#  101,
#  2,
#  1,
#  1,
#  114,
#  20,
#  72,
#  2,
#  1,
#  55,
#  220,
#  1,
#  4,
#  101,
#  41,
#  30,
#  62,
#  3,
#  21,
#  6,
#  20,
#  40,
#  65]
