# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = 'http://www.patentsview.org/api/locations/query?q={"inventor_last_name":["cardozo","lewis","duperval"]}&f=["assignee_lastknown_city","assignee_lastknown_state","assignee_lastknown_country"]'

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# {'locations': [{'assignees': [{'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '326745'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '9731'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '329786'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '77129'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '16873'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '243098'}, {'assignee_lastknown_city': 'Garland', 'assignee_lastknown_state': 'TX', 'assignee_lastknown_country': 'US', 'assignee_key_id': '127202'},
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 25,
#     "locations": [
#         {
#             "assignees": [
#                 {
#                     "assignee_key_id": "326745",
#                     "assignee_lastknown_city": "Garland",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "TX"
#                 },
#                 {
#                     "assignee_key_id": "9731",
#                     "assignee_lastknown_city": "Garland",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "TX"
#                 },
#                 {
#                     "assignee_key_id": "329786",
#                     "assignee_lastknown_city": "Garland",
#                     "assignee_lastknown_country": "US",
#                     "assignee_lastknown_state": "TX"
#                 },
#                 {
#                     "assignee_key_id": "77129",
# ...

# %%
for row in range(len(response)):
    #First I load the dict (one at a time)
    n = response.loc[row,'dict_column']
    #Now I make a new column that pulls out the data that I want.
    response.loc[row,'new_column'] = n.get('key')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6be35edb0b55> in <module>
#       1 for row in range(len(response)):
#       2     #First I load the dict (one at a time)
# ----> 3     n = response.loc[row,'dict_column']
#       4     #Now I make a new column that pulls out the data that I want.
#       5     response.loc[row,'new_column'] = n.get('key')
#
# AttributeError: 'dict' object has no attribute 'loc'

# %%
response.keys()
# Out:
# dict_keys(['locations', 'count', 'total_location_count'])

# %%
from pandas.io.json import json_normalize
df = pd.DataFrame.from_dict(json_normalize(response), orient='columns')

# %%
df.T
# Out:
#                                                                       0
# count                                                                25
# locations             [{'assignees': [{'assignee_lastknown_city': 'G...
# total_location_count                                               1898

# %%
import pandas as pd
df=pd.io.json.json_normalize(response['locations'])
df
# Out:
#                                             assignees
# 0   [{'assignee_lastknown_city': 'Garland', 'assig...
# 1   [{'assignee_lastknown_city': 'Brunswick', 'ass...
# 2   [{'assignee_lastknown_city': 'Lakeland', 'assi...
# 3   [{'assignee_lastknown_city': 'Upton', 'assigne...
# 4   [{'assignee_lastknown_city': None, 'assignee_l...
# 5   [{'assignee_lastknown_city': 'St. Inigoes', 'a...
# 6   [{'assignee_lastknown_city': 'Leicester', 'ass...
# 7   [{'assignee_lastknown_city': 'Winfield', 'assi...
# 8   [{'assignee_lastknown_city': 'Mt. Prospect', '...
# 9   [{'assignee_lastknown_city': 'Paw Paw', 'assig...
# 10  [{'assignee_lastknown_city': 'Lakehead', 'assi...
# 11  [{'assignee_lastknown_city': 'Loveland', 'assi...
# 12  [{'assignee_lastknown_city': 'Richmond', 'assi...
# 13  [{'assignee_lastknown_city': None, 'assignee_l...
# 14  [{'assignee_lastknown_city': 'Malahat', 'assig...
# 15  [{'assignee_lastknown_city': 'Olathe', 'assign...
# ...
